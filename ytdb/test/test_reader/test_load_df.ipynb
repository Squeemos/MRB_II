# %%
import pandas as pd

# %%
df = pd.read_pickle("df_trending.xz")

# %%
df.thumbnails.iloc[0]
# Out:
# {'default': {'url': 'https://i.ytimg.com/vi/UJ9Iz7HhU-I/default.jpg',
#   'width': 120,
#   'height': 90},
#  'medium': {'url': 'https://i.ytimg.com/vi/UJ9Iz7HhU-I/mqdefault.jpg',
#   'width': 320,
#   'height': 180},
#  'high': {'url': 'https://i.ytimg.com/vi/UJ9Iz7HhU-I/hqdefault.jpg',
#   'width': 480,
#   'height': 360}}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   queryTime             100 non-null    datetime64[ns, UTC]
#  1   kind                  100 non-null    object
#  2   etag                  100 non-null    object
#  3   id                    100 non-null    object
#  4   publishedAt           100 non-null    datetime64[ns, UTC]
#  5   channelId             100 non-null    object
#  6   title                 100 non-null    object
#  7   description           100 non-null    object
#  8   thumbnails            100 non-null    object
#  9   channelTitle          100 non-null    object
#  10  tags                  82 non-null     object
#  11  categoryId            100 non-null    int64
#  12  liveBroadcastContent  100 non-null    object
#  13  localized             100 non-null    object
# ...

# %% [markdown]
# ---

# %%
df2 = pd.read_pickle("https://squeemos.pythonanywhere.com/static/yt_trending.xz")

# %%
df2
# Out:
#                       queryTime  queryTimestamp           kind  \
# 0     2022-09-21 22:00:49+00:00    1.663798e+09  youtube#video
# 1     2022-09-21 22:00:49+00:00    1.663798e+09  youtube#video
# 2     2022-09-21 22:00:49+00:00    1.663798e+09  youtube#video
# 3     2022-09-21 22:00:49+00:00    1.663798e+09  youtube#video
# 4     2022-09-21 22:00:49+00:00    1.663798e+09  youtube#video
# ...                         ...             ...            ...
# 14545 2022-10-04 00:02:45+00:00             NaN  youtube#video
# 14546 2022-10-04 00:02:45+00:00             NaN  youtube#video
# 14547 2022-10-04 00:02:45+00:00             NaN  youtube#video
# 14548 2022-10-04 00:02:45+00:00             NaN  youtube#video
# 14549 2022-10-04 00:02:45+00:00             NaN  youtube#video
#
#                               etag           id               publishedAt  \
# 0      1WoqDj0GgTW88l8XbRLIR7UZEQY  Na2hOcx4uX8 2022-09-19 17:39:21+00:00
# ...
